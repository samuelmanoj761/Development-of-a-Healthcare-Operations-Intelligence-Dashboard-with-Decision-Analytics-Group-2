# %%
import pandas as pd

# %%
df = pd.read_csv("dim_state.csv")

# %%
df.head()
# Out:
#    state_id         state_name     region  latitude  longitude   population  \
# 0         1     Andhra Pradesh      South   15.9129    79.7400   53900000.0
# 1         2  Arunachal Pradesh  Northeast   28.2180    94.7278    1600000.0
# 2         3              Assam  Northeast   26.2006    92.9376   35600000.0
# 3         4              Bihar       East   25.0961    85.3131  124800000.0
# 4         5       Chhattisgarh    Central   21.2787    81.8661   29400000.0
#
#    area_sq_km
# 0      162970
# 1       83743
# 2       78438
# 3       94163
# 4      135192

# %%
df.shape
# Out:
# (32, 7)

# %%
df.dtypes
# Out:
# state_id        int64
# state_name     object
# region         object
# latitude      float64
# longitude     float64
# population    float64
# area_sq_km      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# state_id      0
# state_name    0
# region        0
# latitude      0
# longitude     0
# population    1
# area_sq_km    0
# dtype: int64

# %%
df["population"] = df["population"].fillna(df["population"].median())

# %%
df.isnull().sum()
# Out:
# state_id      0
# state_name    0
# region        0
# latitude      0
# longitude     0
# population    0
# area_sq_km    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   state_id    32 non-null     int64
#  1   state_name  32 non-null     object
#  2   region      32 non-null     object
#  3   latitude    32 non-null     float64
#  4   longitude   32 non-null     float64
#  5   population  32 non-null     float64
#  6   area_sq_km  32 non-null     int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.9+ KB

# %%
df["region"] = df["region"].str.strip()

# %%
df.to_csv("dim_state_cleaned.csv", index=False)
